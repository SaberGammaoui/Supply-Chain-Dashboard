# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:/Users/Gammaoui/Downloads/supply_chain_data.csv')

# %%
df.head()
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                      802
# 1     skincare  SKU1  14.843523            95                      736
# 2     haircare  SKU2  11.319683            34                        8
# 3     skincare  SKU3  61.163343            68                       83
# 4     skincare  SKU4   4.805496            26                      871
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# 1        7460.900065                Female            53          30
# 2        9577.749626               Unknown             1          10
# 3        7766.836426            Non-binary            23          13
# 4        2686.505152            Non-binary             5           3
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# ...

# %%
df.head(10)
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                      802
# 1     skincare  SKU1  14.843523            95                      736
# 2     haircare  SKU2  11.319683            34                        8
# 3     skincare  SKU3  61.163343            68                       83
# 4     skincare  SKU4   4.805496            26                      871
# 5     haircare  SKU5   1.699976            87                      147
# 6     skincare  SKU6   4.078333            48                       65
# 7    cosmetics  SKU7  42.958384            59                      426
# 8    cosmetics  SKU8  68.717597            78                      150
# 9     skincare  SKU9  64.015733            35                      980
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# ...

# %%
df['Customer demographics'].value_counts()
# Out:
# Customer demographics
# Unknown       31
# Female        25
# Non-binary    23
# Male          21
# Name: count, dtype: int64

# %%
df.loc[df['Customer demographics'] == 'Non-binary', 'Customer demographics'] = 'Female'

# %%
df['Customer demographics'].value_counts()
# Out:
# Customer demographics
# Female     48
# Unknown    31
# Male       21
# Name: count, dtype: int64

# %%
df.loc[df['Customer demographics'] == 'Unknown', 'Customer demographics'] = 'Male'

# %%
df['Customer demographics'].value_counts()
# Out:
# Customer demographics
# Male      52
# Female    48
# Name: count, dtype: int64

# %%
df['SKU'].value_counts()
# Out:
# SKU
# SKU0     1
# SKU1     1
# SKU2     1
# SKU3     1
# SKU4     1
#         ..
# SKU95    1
# SKU96    1
# SKU97    1
# SKU98    1
# SKU99    1
# Name: count, Length: 100, dtype: int64

# %%
df
# Out:
#    Product type    SKU      Price  Availability  Number of products sold  \
# 0      haircare   SKU0  69.808006            55                      802
# 1      skincare   SKU1  14.843523            95                      736
# 2      haircare   SKU2  11.319683            34                        8
# 3      skincare   SKU3  61.163343            68                       83
# 4      skincare   SKU4   4.805496            26                      871
# ..          ...    ...        ...           ...                      ...
# 95     haircare  SKU95  77.903927            65                      672
# 96    cosmetics  SKU96  24.423131            29                      324
# 97     haircare  SKU97   3.526111            56                       62
# 98     skincare  SKU98  19.754605            43                      913
# 99     haircare  SKU99  68.517833            17                      627
#
#     Revenue generated Customer demographics  Stock levels  Lead times  \
# ...

# %%
import random
import string

# %%
random.seed(42)

# %%
sku_codes = []

# %%
letter = random.choice(string.ascii_uppercase)
numbers = ''.join([str(random.randint(0, 9)) for _ in range(5)])
sku_code = letter + numbers
print(f"Sample SKU: {sku_code}")
# Out:
# Sample SKU: U10433

# %%
for i in range(99):
    letter = random.choice(string.ascii_uppercase)
    numbers = ''.join([str(random.randint(0, 9)) for _ in range(5)])
    sku_code = letter + numbers
    sku_codes.append(sku_code)

# %%
print(f"Total SKU codes generated: {len(sku_codes)}")
print("First 10 SKU codes:")
for i in range(10):
    print(f"SKU{i+1} -> {sku_codes[i]}")
# Out:
# Total SKU codes generated: 99
# First 10 SKU codes:
# SKU1 -> E18196
# SKU2 -> B01338
# SKU3 -> T08386
# SKU4 -> H79402
# SKU5 -> W65423
# SKU6 -> Y51161
# SKU7 -> L59407
# SKU8 -> R16184
# SKU9 -> U95931
# SKU10 -> B34131

# %%
df.columns
# Out:
# Index(['Product type', 'SKU', 'Price', 'Availability',
#        'Number of products sold', 'Revenue generated', 'Customer demographics',
#        'Stock levels', 'Lead times', 'Order quantities', 'Shipping times',
#        'Shipping carriers', 'Shipping costs', 'Supplier name', 'Location',
#        'Lead time', 'Production volumes', 'Manufacturing lead time',
#        'Manufacturing costs', 'Inspection results', 'Defect rates',
#        'Transportation modes', 'Routes', 'Costs'],
#       dtype='object')

# %%
sku_mapping = {}
for i in range(99):
    old_sku = f"SKU{i+1}"
    new_sku = sku_codes[i]
    sku_mapping[old_sku] = new_sku


df['SKU'] = df['SKU'].replace(sku_mapping)

# %%
print("First 10 SKU values after replacement:")
print(df['SKU'].head(10))
# Out:
# First 10 SKU values after replacement:
# 0      SKU0
# 1    E18196
# 2    B01338
# 3    T08386
# 4    H79402
# 5    W65423
# 6    Y51161
# 7    L59407
# 8    R16184
# 9    U95931
# Name: SKU, dtype: object

# %%
print("Unique SKU values in your data:")
print(df['SKU'].unique())
# Out:
# Unique SKU values in your data:
# ['SKU0' 'E18196' 'B01338' 'T08386' 'H79402' 'W65423' 'Y51161' 'L59407'
#  'R16184' 'U95931' 'B34131' 'M47525' 'L34192' 'R32764' 'U83503' 'B56413'
#  'S53767' 'E42388' 'I96965' 'H28710' 'D22691' 'M69784' 'R01845' 'D46270'
#  'X48281' 'U48932' 'L28809' 'K70154' 'H03911' 'X71822' 'V78248' 'T63834'
#  'M57871' 'H31509' 'R39301' 'W03105' 'C83473' 'R29973' 'Z76311' 'V65667'
#  'X01065' 'Z13338' 'O26247' 'H17810' 'U80132' 'N77360' 'F60647' 'J68723'
#  'J30980' 'X50097' 'Q82081' 'F19136' 'D93990' 'T16998' 'K43534' 'M24751'
#  'A79911' 'R38425' 'C35427' 'R49808' 'J12411' 'X82449' 'G53487' 'I01640'
#  'A52427' 'R68011' 'W28059' 'R26204' 'L05331' 'L86923' 'F26025' 'Z63421'
#  'M07337' 'L43303' 'M54145' 'U86850' 'D42940' 'D96556' 'T81693' 'I06088'
#  'V35615' 'T51484' 'V65648' 'E36629' 'S46804' 'J36995' 'O77387' 'Z21489'
#  'K13433' 'E00379' 'Y17693' 'W67632' 'U01632' 'Z87083' 'D72788' 'T57986'
#  'R72774' 'Y34873' 'I71434' 'K58122']

# %%
df['SKU'] = df['SKU'].replace('SKU0', sku_codes[0])

# %%
print("Check if SKU0 still exists:")
print('SKU0' in df['SKU'].values)
print(f"First few SKU values: {df['SKU'].head().tolist()}")
# Out:
# Check if SKU0 still exists:
# False
# First few SKU values: ['E18196', 'E18196', 'B01338', 'T08386', 'H79402']

# %%
df.to_csv('C:/Users/Gammaoui/Downloads/supply_chain_data.csv', index=False)

# %%
df.columns
# Out:
# Index(['Product type', 'SKU', 'Price', 'Availability',
#        'Number of products sold', 'Revenue generated', 'Customer demographics',
#        'Stock levels', 'Lead times', 'Order quantities', 'Shipping times',
#        'Shipping carriers', 'Shipping costs', 'Supplier name', 'Location',
#        'Lead time', 'Production volumes', 'Manufacturing lead time',
#        'Manufacturing costs', 'Inspection results', 'Defect rates',
#        'Transportation modes', 'Routes', 'Costs'],
#       dtype='object')

# %%
print("Current supplier names:")
print(df['Supplier name'].value_counts())
# Out:
# Current supplier names:
# Supplier name
# Supplier 1    27
# Supplier 2    22
# Supplier 5    18
# Supplier 4    18
# Supplier 3    15
# Name: count, dtype: int64

# %%
real_suppliers = [
    "Unilever Supply Chain",
    "Procter & Gamble Materials",
    "L'Oréal Ingredients",
    "Henkel Beauty Care",
    "Kao Corporation Supply"
]

# %%
supplier_mapping = {}
for i in range(1, 6):  # Supplier 1 to Supplier 5
    old_name = f"Supplier {i}"
    new_name = real_suppliers[i-1]
    supplier_mapping[old_name] = new_name
    print(f"{old_name} -> {new_name}")
# Out:
# Supplier 1 -> Unilever Supply Chain
# Supplier 2 -> Procter & Gamble Materials
# Supplier 3 -> L'Oréal Ingredients
# Supplier 4 -> Henkel Beauty Care
# Supplier 5 -> Kao Corporation Supply

# %%
df['Supplier name'] = df['Supplier name'].replace(supplier_mapping)

# %%
print("Updated supplier names:")
print(df['Supplier name'].value_counts())
# Out:
# Updated supplier names:
# Supplier name
# Unilever Supply Chain         27
# Procter & Gamble Materials    22
# Kao Corporation Supply        18
# Henkel Beauty Care            18
# L'Oréal Ingredients           15
# Name: count, dtype: int64

# %%
df.to_csv('C:/Users/Gammaoui/Downloads/supply_chain_data.csv', index=False)

# %%
real_suppliers = [
    "Unilever",
    "Procter&Gamble",
    "LOreal",
    "Henkel Beauty",
    "Kao Corporation"
]

# %%
supplier_mapping = {}
for i in range(1, 6):  # Supplier 1 to Supplier 5
    old_name = f"Supplier {i}"
    new_name = real_suppliers[i-1]
    supplier_mapping[old_name] = new_name
    print(f"{old_name} -> {new_name}")
# Out:
# Supplier 1 -> Unilever
# Supplier 2 -> Procter&Gamble
# Supplier 3 -> LOreal
# Supplier 4 -> Henkel Beauty
# Supplier 5 -> Kao Corporation

# %%
df['Supplier name'] = df['Supplier name'].replace(supplier_mapping)

# %%
print("Updated supplier names:")
print(df['Supplier name'].value_counts())
# Out:
# Updated supplier names:
# Supplier name
# Unilever Supply Chain         27
# Procter & Gamble Materials    22
# Kao Corporation Supply        18
# Henkel Beauty Care            18
# L'Oréal Ingredients           15
# Name: count, dtype: int64

# %%
df['Supplier name'] = df['Supplier name'].replace(supplier_mapping)

# %%
print("Updated supplier names:")
print(df['Supplier name'].value_counts())
# Out:
# Updated supplier names:
# Supplier name
# Unilever Supply Chain         27
# Procter & Gamble Materials    22
# Kao Corporation Supply        18
# Henkel Beauty Care            18
# L'Oréal Ingredients           15
# Name: count, dtype: int64

# %%
df.to_csv('C:/Users/Gammaoui/Downloads/supply_chain_data.csv', index=False)

# %%
print("Current supplier names in dataframe:")
print(df['Supplier name'].unique())
# Out:
# Current supplier names in dataframe:
# ["L'Oréal Ingredients" 'Unilever Supply Chain' 'Kao Corporation Supply'
#  'Henkel Beauty Care' 'Procter & Gamble Materials']

# %%
supplier_mapping = {
    "Unilever Supply Chain": "Unilever",
    "Procter & Gamble Materials": "Procter&Gamble", 
    "L'Oréal Ingredients": "LOreal",
    "Henkel Beauty Care": "Henkel Beauty",
    "Kao Corporation Supply": "Kao Corporation"
}
print("Mapping:")
for old, new in supplier_mapping.items():
    print(f"{old} -> {new}")
# Out:
# Mapping:
# Unilever Supply Chain -> Unilever
# Procter & Gamble Materials -> Procter&Gamble
# L'Oréal Ingredients -> LOreal
# Henkel Beauty Care -> Henkel Beauty
# Kao Corporation Supply -> Kao Corporation

# %%
df['Supplier name'] = df['Supplier name'].replace(supplier_mapping)

# %%
print("Updated supplier names:")
print(df['Supplier name'].unique())
# Out:
# Updated supplier names:
# ['LOreal' 'Unilever' 'Kao Corporation' 'Henkel Beauty' 'Procter&Gamble']

# %%
df.to_csv('C:/Users/Gammaoui/Downloads/supply_chain_data.csv', index=False)

# %%
import os
print("Current directory:", os.getcwd())
print("Files in directory:", os.listdir('.'))
# Out:
# Current directory: C:\Users\Gammaoui
# ...
